# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakesh684-dot/Deep-Learning-Car-Brand/blob/master/NLP4Health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers datasets sentencepiece torch accelerate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# List files in the specified directory
files = os.listdir('/content/drive/MyDrive')

# Print the list of files
print("Files in '/content/drive/MyDrive':")
for file in files:
    print(file)
# Out:
# Files in '/content/drive/MyDrive':
# Colab Notebooks
# Screenshot_20240523_115408~2.jpg
# Classroom
# Resources @ NLP-MT Lab
# new food  menu.pdf

# %%
# यह कमांड ZIP फाइल को आपके गूगल ड्राइव से Colab की मेमोरी में अनज़िप कर देगा
# -d "/content/dataset/" का मतलब है कि सारी फाइलें "dataset" नाम के एक नए फोल्डर में जाएंगी

# !unzip "/content/drive/My Drive/Copy of SharedTask_NLPAI4Health_Train&dev_set.zip" -d "/content/dataset/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_0d1ece9d17bd4274981ca3e09b32cf57_IDX_05_2.jsonl
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_1e719e67b8db4e7ea7d4a3a5cabe3790_IDX_03_0.jsonl
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_2a2447da620e46aeb41425d485d1a350_IDX_04_0.jsonl
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_6c42d0d7db1f4efea4dcb6839b27e5e8_IDX_03_1.jsonl
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_9e6f14028a9f4661a5b5bc31ae9de3ea_IDX_01_4.jsonl
#   inflating: /content/dataset/SharedTask_NLPAI4Health_Train&dev_set/train/Dogri/Dialogues/scenario_15_17e5328199964258bbf86a8e5ea042de_IDX_00_0.jsonl
# ...
